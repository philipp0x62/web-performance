# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg

# %matplotlib inline 
# %reload_ext autoreload 
# %autoreload 2

# %%
# import data 

#Please note: the experiment had to be repeated several times, therefore has_website has most likely been wrongly set
# Instead use: har_file

db = psycopg.connect(dbname='web_performance_final')
#db = psycopg.connect(dbname='complexity_analysis')
cursor = db.cursor()
#res = cursor.execute("SELECT dns, number_queried_servers  FROM websites ORDER BY number_queried_servers DESC LIMIT 50")
#print(cursor.fetchall())

# import data 
website_df = pd.read_sql_query("SELECT * FROM websites", db)
mime_types_df = pd.read_sql_query("SELECT * FROM mime_types", db)
measurements_df = pd.read_sql_query("SELECT * FROM measurements", db)

# %%
cursor.execute("SELECT COUNT(*) FROM websites")
domains_count = cursor.fetchone()[0]

cursor.execute("SELECT COUNT(*) FROM websites WHERE har_file=True")
website_count = cursor.fetchone()[0]
#website_count = 719281

cursor.execute("SELECT COUNT(*) FROM websites WHERE har_file=True AND has_error=True")
error_pages = cursor.fetchone()[0]

cursor.execute("SELECT COUNT(*) FROM websites WHERE har_file=True AND has_error=False")
none_error_pages = cursor.fetchone()[0]

print('domains offering a website ', website_count, '/', domains_count)
print('error encounter, no page provided ', domains_count-website_count, '/', domains_count)
print('domains displaying an error page ', error_pages, '/', domains_count)
print('domains displaying no error page ', none_error_pages, '/', domains_count)
# Out:
# domains offering a website  572345 / 1000000
# error encounter, no page provided  427655 / 1000000
# domains displaying an error page  572345 / 1000000
# domains displaying no error page  0 / 1000000

# %%
# Out:
# domains offering a website  572345 / 1000000
# error encounter, no page provided  0 / 1000000
# domains displaying an error page  572345 / 1000000

# %%
# website complexity statisitics
median_objects = website_df['number_objects_loaded'].median()
mean_objects = website_df['number_objects_loaded'].mean()

median_queried_servers = website_df['number_queried_servers'].median()
mean_queried_servers = website_df['number_queried_servers'].mean()

median_non_origin_servers = website_df['number_non_origin_servers'].median()
mean_non_origin_servers = website_df['number_non_origin_servers'].mean()

median_mime_types = website_df['number_mime_types'].median()
mean_mime_types = website_df['number_mime_types'].mean()

median_bytes_downladed = website_df['bytes_downladed'].div(1024).div(1024).median()
mean_bytes_downladed = website_df['bytes_downladed'].div(1024).div(1024).mean()


print('median number of objects ', median_objects)
print('mean number of objects ', mean_objects)
print('median queried servers ', median_queried_servers)
print('mean queried servers ', mean_queried_servers)
print('median non origin servers ', median_non_origin_servers)
print('mean non origin servers ', mean_non_origin_servers)
print('median number of mime types ', median_mime_types)
print('mean number of mime types ', mean_mime_types)
print('median bytes downloaded ', median_bytes_downladed, ' MB')
print('mean bytes downloaded ', mean_bytes_downladed, ' MB')
# Out:
# median number of objects  42.0
# mean number of objects  62.98801441995548
# median queried servers  7.0
# mean queried servers  9.634270889958167
# median non origin servers  5.0
# mean non origin servers  8.44912628027155
# median number of mime types  11.0
# mean number of mime types  10.818130883479474
# median bytes downloaded  1.2021608352661133  MB
# mean bytes downloaded  2.842003255631863  MB

# %%
# add needed performance metrics

# clean measurements
cleaned_measurements_df = measurements_df[measurements_df['error'] == '']
cleaned_measurements_df = cleaned_measurements_df[cleaned_measurements_df['loadeventend'] != 0]
cleaned_measurements_df = cleaned_measurements_df[cleaned_measurements_df['firstcontentfulpaint'] != 0]
warmed_up_measurements_df = cleaned_measurements_df[cleaned_measurements_df['cachewarming'] == 0]

# neeeded columns
warmed_up_measurements_df['web_duration'] = warmed_up_measurements_df['loadeventend'] - warmed_up_measurements_df['fetchstart']


# find intersect measurements
domains_counted = warmed_up_measurements_df.groupby('domain', as_index=False)['domain'].agg({'count':'count'})
intersect_domains = domains_counted[domains_counted['count'] == 3]
intersect_measurements = warmed_up_measurements_df[warmed_up_measurements_df['domain'].isin(intersect_domains['domain'])]


# create penalty columns
scatterplot_df = intersect_measurements[['domain','web_duration', 'protocol', 'firstcontentfulpaint']]

q_h_scatterplot_df = scatterplot_df[scatterplot_df['protocol'] != 'udp']
u_scatterplot_df = scatterplot_df[scatterplot_df['protocol'] == 'udp']
u_scatterplot_df = u_scatterplot_df.rename(columns={'web_duration': 'web_duration_udp', 'firstcontentfulpaint': 'firstcontentfulpaint_udp'})

q_h_scatterplot_df['performance_penalty_web_duration'] = q_h_scatterplot_df['web_duration'] 
q_h_scatterplot_df['performance_penalty_firstcontentfulpaint'] = q_h_scatterplot_df['firstcontentfulpaint']

q_h_scatterplot_merge_df = pd.merge(q_h_scatterplot_df, u_scatterplot_df, how='inner', on='domain')

q_h_scatterplot_merge_df['performance_penalty_web_duration'] = q_h_scatterplot_merge_df['performance_penalty_web_duration'] - q_h_scatterplot_merge_df['web_duration_udp'] 
q_h_scatterplot_merge_df['performance_penalty_firstcontentfulpaint'] = q_h_scatterplot_merge_df['performance_penalty_firstcontentfulpaint'] - q_h_scatterplot_merge_df['firstcontentfulpaint_udp']

q_h_scatterplot_merge_df = q_h_scatterplot_merge_df.rename(columns={'protocol_x': 'protocol'})
# Out:
# /var/folders/gg/mshnyrc13_xds3zrlmd3_nkc0000gn/T/ipykernel_5854/1953754078.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   warmed_up_measurements_df['web_duration'] = warmed_up_measurements_df['loadeventend'] - warmed_up_measurements_df['fetchstart']
# /var/folders/gg/mshnyrc13_xds3zrlmd3_nkc0000gn/T/ipykernel_5854/1953754078.py:14: FutureWarning: Passing a dictionary to SeriesGroupBy.agg is deprecated and will raise in a future version of pandas. Pass a list of aggregations instead.
#   domains_counted = warmed_up_measurements_df.groupby('domain', as_index=False)['domain'].agg({'count':'count'})
# /var/folders/gg/mshnyrc13_xds3zrlmd3_nkc0000gn/T/ipykernel_5854/1953754078.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q_h_scatterplot_df['performance_penalty_web_duration'] = q_h_scatterplot_df['web_duration']
# /var/folders/gg/mshnyrc13_xds3zrlmd3_nkc0000gn/T/ipykernel_5854/1953754078.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q_h_scatterplot_df['performance_penalty_firstcontentfulpaint'] = q_h_scatterplot_df['firstcontentfulpaint']

# %%
# merge penalty columns with website table

# %%
q_scatterplot_merge_df = q_h_scatterplot_merge_df[q_h_scatterplot_merge_df['protocol'] == 'quic'] 
h_scatterplot_merge_df = q_h_scatterplot_merge_df[q_h_scatterplot_merge_df['protocol'] == 'h3']

website_df_insersect = pd.merge(website_df, q_scatterplot_merge_df, how='inner',left_on='dns', right_on='domain')
website_df_insersect = website_df_insersect.rename(columns={'web_duration': 'web_duration_quic', 'firstcontentfulpaint': 'firstcontentfulpaint_quic', 'performance_penalty_web_duration': 'performance_penalty_web_duration_quic', 'performance_penalty_firstcontentfulpaint': 'performance_penalty_firstcontentfulpaint_quic'})
website_df_insersect = website_df_insersect.drop(['protocol', 'protocol_y'], axis=1)
website_df_insersect = pd.merge(website_df_insersect, h_scatterplot_merge_df, how='inner',left_on='dns', right_on='domain')
website_df_insersect = website_df_insersect.rename(columns={'web_duration': 'web_duration_h3', 'firstcontentfulpaint': 'firstcontentfulpaint_h3', 'performance_penalty_web_duration': 'performance_penalty_web_duration_h3', 'performance_penalty_firstcontentfulpaint': 'performance_penalty_firstcontentfulpaint_h3'})     
website_df_insersect = website_df_insersect.drop(['protocol','protocol_y', 'domain_x', 'web_duration_udp_x', 'firstcontentfulpaint_udp_x', 'domain_y'], axis=1)                                
website_df_insersect = website_df_insersect.rename(columns={'web_duration_udp_y': 'web_duration_udp', 'firstcontentfulpaint_udp_y': 'firstcontentfulpaint_udp'})

# %%
# correletion between website properties and DoE impact on loading time
website_df_insersect_cleaned_corr = website_df_insersect.drop(['has_website','has_error', 'har_file', '_id'], axis=1)
correlation_df = website_df_insersect_cleaned_corr.corr(numeric_only=True)

# %%
intersect_domains
# Out:
#                       domain  count
# 7                     001.bj      3
# 16                004gmbh.de      3
# 23               007cctv.com      3
# 25      007onlinecasino.club      3
# 26       007onlinecasino.net      3
# ...                      ...    ...
# 429028            zzhczs.com      3
# 429036          zzkaizhi.com      3
# 429074         zztuoying.com      3
# 429076           zzwangu.com      3
# 429085         zzy73aomb.com      3
#
# [42860 rows x 2 columns]

# %%
correlation_performance_df = correlation_df.drop(['web_duration_quic', 'firstcontentfulpaint_quic', 'web_duration_h3', 'firstcontentfulpaint_h3', 'web_duration_udp', 'firstcontentfulpaint_udp'], axis=1)   
correlation_loading_df = correlation_df.drop(['performance_penalty_web_duration_quic', 'performance_penalty_firstcontentfulpaint_quic', 'performance_penalty_web_duration_h3', 'performance_penalty_firstcontentfulpaint_h3'], axis=1)

correlation_performance_df = correlation_performance_df.drop(['web_duration_quic', 'firstcontentfulpaint_quic', 'web_duration_h3', 'firstcontentfulpaint_h3', 'web_duration_udp', 'firstcontentfulpaint_udp'], axis=0)   
correlation_loading_df = correlation_loading_df.drop(['performance_penalty_web_duration_quic', 'performance_penalty_firstcontentfulpaint_quic', 'performance_penalty_web_duration_h3', 'performance_penalty_firstcontentfulpaint_h3'], axis=0)

# %%
plt.figure(figsize=(16, 10))
sns.heatmap(correlation_performance_df, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16, 10))
sns.heatmap(correlation_loading_df, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
mime_types_df
# Out:
#          website_id                       mime_type  occurences  \
# 0            893169                       text/html           2
# 1            893169        text/html; charset=UTF-8           1
# 2            893169                        text/css          43
# 3            893169         text/css; charset=utf-8           4
# 4            893169  text/javascript; charset=utf-8           2
# ...             ...                             ...         ...
# 7781271      350849              application/binary           1
# 7781272      350849                      image/webp           1
# 7781273      909838        application/octet-stream           6
# 7781274      909838        text/html; charset=UTF-8           1
# 7781275      909838                                           1
#
#          bytes_body_download  bytes_header_download
# 0                       1733                    589
# 1                      28332                    540
# 2                     439589                  15637
# 3                       9151                   4056
# 4                        722                   1592
# ...                      ...                    ...
# 7781271                    0                    640
# 7781272               109812                   1102
# 7781273                79868                   2746
# 7781274                18078                    432
# 7781275                   -1                     -1
#
# [7781276 rows x 5 columns]

# %%
mime_type_list = list(mime_types_df['mime_type'].unique())
mime_type_set = set([x.split(';')[0] for x in mime_type_list])
# Out:
# {'', 'text/javascript  charset=utf-8', 'imag/x-icon', 'Application/JSON', 'ttf', 'video/m4v', 'Content-Type: image/png', 'application/ljson', 'image/x-png', 'text/vnd.trolltech.linguist', 'application/x-javascript, charset=UTF-8', 'application/fontwoff2', 'application/postscript', 'woff type', 'PNG32', 'font/x-webp', 'application/image/svg+xml', 'text/srt', '"font/woff2"', 'application/vnd.google.octet-stream-compressible', 'application/vnd.scaleofuniverse.dave', 'i', 'application/x-javascript', 'image/icon', 'image/JPG', 'image/x-icon', 'application/pgp-keys', 'application/schema+json', 'webp/image', 'text/richtext', 'image/vnd.microsoft.icon', 'image/bmp', 'vnd.travelcircus.campaign.collection+json', 'image/jfif', 'application/vnd.solid-v1.0+json', 'application/node', 'text/css,text/html', 'image/tif', 'application/linkset+json', 'application/json, charset=utf-8,text/html, charset=utf-8', 'application/vnd.microsoft.appconfig.kvset+json', '$contentType', 'javascript/vue', 'application/x-empty', 'text/*', 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'image/JPEG', 'text/text', 'Text/plain', 'images/x-icon', 'image/x-xbitmap', 'Origin', 'application/wasm', 'js', 'max-age=31536000', 'application/x-asciicast', 'application/font/opentype', 'application/activity+json', 'JPEG', 'application/vnd.unity', 'application/json+protobuf', 'application/vnd.kafka.v2+json', 'audio/x-mpegurl', 'application/font-woff', 'application/fot-woff2', 'video/iso.segment', '#<Mime::NullType:0x0000742ee827ed00>', 'application/vnd.kafka.json.v2+json', 'APPLICATION/X-WOFF', 'application/vnd.medchat+json', 'undefined', 'application/font-woff2,8888888888888888', 'font/x-font-ttf', 'text/octet', 'application/x-trash', 'application/hr+json', 'application/vnd.sun.wadl+xml', 'image/tiff', 'image/undefined', 'image/jpeg ', 'img/gif', 'application/jsonp', 'file/unknown', 'video/mpeg4', 'text/html, charset=utf-8', 'application/woff2', 'binary/data', 'text/javascript,8888888888888888', 'image/font-woff+.woff', 'text/x-adasrc', 'apr 16, 2019 12:16:15 pm org.apache.tika.config.initializableproblemhandler$3 handleinitializablepro', 'application/vnd.groove-tool-template', 'font/font-woff', 'text/css,8888888888888888', 'javascript', 'application/externalcontentlibrary', 'assets/fonts/woff2/', 'text/base64.jpg', 'text/HTML', 'utf-8', 'image/.pdf', 'image/svg', 'json/application', 'dealnews/json', 'application/octet-stream,text/html', '1644236285517.png', 'application/x-httpd-ea-php72', 'application/vnd.citrix.authenticateresponse-1+xml', 'application/font-woff-2', 'image/xicon', 'application/.woff2', '.gif', '%0d%0a\t\t\tapplication/x-font-woff%0d%0a', '"application/json', 'text/vtt', 'application/vnd.contentful.delivery.v1+json', 'application/json ', 'font/woff2|application/octet-stream|font/x-woff2', 'im', 'video/mgep', 'application/font-woff2.woff2', 'text/fragment+html', 'img/jpg', 'x-application/woff2', 'application/x-ilcs', 'application/ogg', 'text/yaml', 'apllication/woff2', 'gif', 'text/html, charset=UTF-8', 'application/x-octet-stream', 'application/vnd.lotus-organizer', 'text/uri-list', 'Image/svg+xml', 'riot/tag', 'aug 17, 2018 1:18:20 pm org.apache.tika.config.initializableproblemhandler$3 handleinitializableprob', 'text/img', 'application/x-font/woff', 'image/.png', '18', 'IMAGE/PNG', 'img/jpeg', 'application/search-v1+json', 'audio/mpeg3', 'application/vnd.wolfram.mathematica.package', 'application/x-font-tff', 'text/x-go', 'video/MP2T', 'text/html,text/html', 'text/ecmascript', 'application/vnd.chats.chatapi.userinfo.out.v1+json', 'application/x-opentype', 'application/problem+json', 'Jpeg', 'text/x-json', 'application/x.prottp', 'application/otf', 'image/9', 'text/plain', 'appliction/json', 'image/json', 'applicaton/json', 'video/x-m4v', 'HTTP/1.0 200', 'application/json, text/html, text/plain, image/png, text/csv', 'application/transit+json', 'application/octetstream', '"application/json"', 'Application/javascript', 'application/vnd. ...

# %%
mime_types_counted = mime_types_intersect_df.groupby('mime_type', as_index=False)['mime_type'].agg({'count':'count'})
intersect_domains = domains_counted[domains_counted['count'] == 3] # sort and print 

#mime_types_intersect_df
#domains_counted = warmed_up_measurements_df.groupby('domain', as_index=False)['domain'].agg({'count':'count'})
# Out:
# {'',
#  '"application/json',
#  '"application/json"',
#  '"application/x-binary"',
#  '"font/woff2"',
#  '"text/html',
#  '#<Mime::NullType:0x000000078901a0>',
#  '#<Mime::NullType:0x0000000c936e88>',
#  '#<Mime::NullType:0x0000002db26a88>',
#  '#<Mime::NullType:0x00000044e62910>',
#  '#<Mime::NullType:0x0000742ee827ed00>',
#  '$contentType',
#  '$mime',
#  '$mimetype',
#  '%0d%0a\t\t\tapplication/x-font-woff%0d%0a',
#  "'font/woff2'",
#  "('image/gif', None)",
#  '(null)',
#  '(null)/ico',
#  '(null)/woff2',
#  '*',
#  '*/*',
#  ',image/jpeg',
#  '-',
#  '.JPG',
#  '.PNG',
#  '.bmp',
#  '.gif',
#  '.jpeg',
#  '.jpg',
#  '.js',
#  '.png',
#  '.webp',
#  '/image/jpeg',
#  '/image/jpg',
#  '/image/png',
#  '/wp-content/themes/theme-missionfoods-wordpress-main/builder/dist/assets/fonts/slick.woff',
#  '/wp-content/themes/theme-missionfoods-wordpress-main/builder/dist/fonts/MerloNeueRound-Medium_2.woff2',
#  '1',
#  '16',
#  '1644236285517.png',
#  '18',
#  '2',
#  '200',
#  '3',
#  ': text/html',
#  'APPLICATION/X-WOFF',
#  'Access-Control-Allow-Methods: GET',
#  'Application/JSON',
#  'Application/javascript',
#  'Application/json',
#  'Application/test',
#  'Application/ttf',
#  'Application/woff',
#  'Application/x-javascript',
#  'Application/xml',
#  'Content-Type',
#  'Content-Type: application/json',
#  'Content-Type: image/gif',
#  'Content-Type: image/jpeg',
#  'Content-Type: image/png',
#  'Content-Type: image/webp',
#  'Content-Type: text/html',
#  'Content-type: application/force-download',
#  'Content-type: application/json',
#  'Content-type: image/jpeg',
#  'Content-type: image/png',
#  'ContentType',
#  'HTTP/1.0 200',
#  'ICO',
#  'IMAGE',
#  'IMAGE/PNG',
#  'Image',
#  'Image/.jpg',
#  'Image/BMP',
#  'Image/GIF',
#  'Image/Gif',
#  'Image/JPEG',
#  'Image/JPG',
#  'Image/Jpeg',
#  'Image/PNG',
#  'Image/Png',
#  'Image/gif',
#  'Image/ico',
#  'Image/jpeg',
#  'Image/jpg',
#  'Image/png',
#  'Image/svg+xml',
#  'Image/webp',
#  'JPEG',
#  'JPG',
#  'JSON',
#  'Jpeg',
#  'Jpg',
#  'Location',
#  'Multiple files',
#  'None',
#  'Origin',
#  'PNG',
#  'PNG32',
#  'Png',
#  'TEXT/CSS',
#  'TOUT',
#  'Text/html',
#  'Text/plain',
#  'UTF-8',
#  'Unknown',
#  'WebP',
#  "Welbee's Logo_RGB-Green.jpg",
#  'additive=v',
#  'aplication/xap-font-woff',
#  'apllication/woff2',
#  'app/json',
#  'applcation/json',
#  'applecation/json',
#  'appliation/javascript',
#  'applicaiton/font-woff2',
#  'applicaiton/octet-stream',
#  'application',
#  'application / javascript',
#  'application / x-javascript',
#  'application-download',
#  'application.font-woff',
#  'application.json',
#  'application/.jpg',
#  'application/.woff2',
#  'application/1.1.0+json',
#  'application/JSON',
#  'application/JavaScript',
#  'application/Javascript',
#  'application/Json',
#  'application/activity+json',
#  'application/all',
#  'application/argaam.specific+json',
#  'application/atom+xml',
#  'application/base64',
#  'application/binary',
#  'application/com.goodtrust-v1+json',
#  'application/dash+xml',
#  'application/doom',
#  'application/download',
#  'application/ecmascript',
#  'application/edn',
#  'application/encrypted-json',
#  'application/externalcontentlibrary',
#  'application/feed+json',
#  'application/font',
#  'application/font-otf',
#  'application/font-sfnt',
#  'application/font-ttf',
#  'application/font-wof',
#  'application/font-woff',
#  'application/font-woff-2',
#  'application/font-woff2',
#  'application/font-woff2,8888888888888888',
#  'application/font-woff2.woff2',
#  'application/font/opentype',
#  'application/font/otf',
#  'application/font/woff2',
#  'application/font2',
#  'application/font=woff2',
#  'application/fontwoff2',
#  'application/force-download',
#  'application/fot-woff2',
#  'application/fractals',
#  'application/front-woff',
#  'application/front-woff2',
#  'application/geo+json',
#  'application/go',
#  'application/graphql-response+json',
#  'application/grpc-web',
#  'application/grpc-web+proto',
#  'application/grpc-web-text',
#  'application/grpc-web-text+proto',
#  'application/gzip',
#  'application/hal+json',
#  'application/hbpro+ld+json',
#  'application/hr+json',
#  'application/html',
#  'application/ico',
#  'application/image/svg+xml',
#  'application/importmap+json',
#  'application/ion+json',
#  'application/javascript',
#  'application/javascript,8888888888888888',
#  'application/javascript,application/javascript',
#  'application/javascript,application/x-javascript',
#  'application/javascript,text/html',
#  'application/javascript,text/plain',
#  'application/javascriptapplication/x-javascript',
#  'application/javascriptapplication/x-javascripttext/javascript',
#  'application/javascriptp',
#  'application/javascrixpt',
#  'application/jecma.api-v1_0+json',
#  'application/jpeg',
#  'application/jpg',
#  'application/js',
#  'application/json',
#  'application/json ',
#  'application/json charset=UTF-8',
#  'application/json charset=utf-8',
#  'application/json+protobuf',
#  'application/json, charset=utf-8',
#  'application/json, charset=utf-8,application/json, charset=utf-8',
#  'application/json, charset=utf-8,application/json, charset=utf-8,application/json, charset=utf-8',
#  'application/json, charset=utf-8,text/html, charset=utf-8',
#  'application/json, text/html, text/plain, image/png, text/csv',
#  'application/json, text/javascript',
#  'application/json, text/javascript, */*',
#  'application/json, utf-8',
#  'application/json, utf8',
#  'application/json,application/json',
#  'application/json,charset=utf-8',
#  'application/json,text/javascript',
#  'application/json-rpc',
#  'application/jsonp',
#  'application/jwk-set+json',
#  'application/jwt',
#  'application/ld+json',
#  'application/linkset+json',
#  'application/liquid',
#  'application/ljson',
#  'application/manifest+json',
#  'application/media.geo-v2+json',
#  'application/mp4',
#  'application/msword',
#  'application/multipart-formdata',
#  'application/node',
#  'application/ocsp-response',
#  'application/oct-stream',
#  'application/octect-stream',
#  'application/octer-stream',
#  'application/octet',
#  'application/octet-stream',
#  'application/octet-stream Charset=UTF-8',
#  'application/octet-stream,8888888888888888',
#  'application/octet-stream,application/json',
#  'application/octet-stream,text/html',
#  'application/octet-stream,text/plain',
#  'application/octetstream',
#  'application/ogg',
#  'application/openapi+json',
#  'application/opensearchdescription+xml',
#  'application/opentype',
#  'application/otf',
#  'application/partytown',
#  'application/pdf',
#  'application/perl',
#  'application/pgp-keys',
#  'application/png',
#  'application/postscript',
#  'application/problem+json',
#  'application/protobuf',
#  'application/rdf+xml',
#  'application/relax-ng-compact-syntax',
#  'application/rss+xml',
#  'application/schema+json',
#  'application/scytale',
#  'application/search-v1+json',
#  'application/smil',
#  'application/text',
#  'application/text-html',
#  'application/thrift',
#  'application/transit+json',
#  'application/truetype',
#  'application/ttf',
#  'application/txt',
#  'application/unblu-serialized-object',
#  'application/unknown',
#  'application/vnd.adobe.error-response+json',
#  'application/vnd.adobe.flash.movie',
#  'application/vnd.adobe.xt.app-card-v1+json',
#  'application/vnd.ajns.kitchenstories+json',
#  'application/vnd.alturos.ecommerce.b2capi+json',
#  'application/vnd.android.package-archive',
#  'application/vnd.api+json',
#  'application/vnd.apple.mpegurl',
#  'application/vnd.ard.page+json',
#  'application/vnd.autoplac.pl-3+json',
#  'application/vnd.autoplac.pl-4+json',
#  'application/vnd.bestbuy+json',
#  'application/vnd.blueapron.com.v20150501+json',
#  'application/vnd.bluetooth.ep.oob',
#  'application/vnd.breuninger.kauf.warenkorb+json',
#  'application/vnd.cas.services+yaml',
#  'application/vnd.chats.chatapi.config.out.v1+json',
#  'application/vnd.chats.chatapi.userinfo.out.v1+json',
#  'application/vnd.citrix.authenticateresponse-1+xml',
#  'application/vnd.contentful.delivery.v1+json',
#  'application/vnd.contentful.management.v1+json',
#  'application/vnd.df.user.v1+json',
#  'application/vnd.dpexpo.v1+json',
#  'application/vnd.ebica.booking.reservable_period+json',
#  'application/vnd.ebica.booking.shop.info+json',
#  'application/vnd.ebica.booking.v2.shops.shop+json',
#  'application/vnd.ebica.booking.v2_times+json',
#  'application/vnd.geo+json',
#  'application/vnd.github.v3.raw',
#  'application/vnd.google-earth.kml+xml',
#  'application/vnd.google-earth.kmz',
#  'application/vnd.google.octet-stream-compressible',
#  'application/vnd.groove-tool-template',
#  'application/vnd.imgur.v1+json',
#  'application/vnd.infobip.livechat+json',
#  'application/vnd.inin.icws+JSON',
#  'application/vnd.intershop.basket.v1+json',
#  'application/vnd.intershop.configuration.v1+json',
#  'application/vnd.kafka.json.v2+json',
#  'application/vnd.kafka.v2+json',
#  'application/vnd.koan',
#  'application/vnd.lequipe.mt+json',
#  'application/vnd.live-list+json',
#  'application/vnd.lotus-organizer',
#  'application/vnd.mapbox-vector-tile',
#  'application/vnd.maxmind.com-city+json',
#  'application/vnd.maxmind.com-country+json',
#  'application/vnd.maxmind.com-error+json',
#  'application/vnd.maxmind.com-insights+json',
#  'application/vnd.medchat+json',
#  'application/vnd.microsoft.appconfig.kvset+json',
#  'application/vnd.mixtape-list+json',
#  'application/vnd.ms-excel',
#  'application/vnd.ms-fontobject',
#  'application/vnd.ms-opentype',
#  'application/vnd.nal.v1.2021+json',
#  'application/vnd.oasis.opendocument.formula-template',
#  'application/vnd.ogc.se_xml',
#  'application/vnd.ogc.sld+xml',
#  'application/vnd.ogc.wms_xml',
#  'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#  'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#  'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#  'application/vnd.osk.theorypack',
#  'application/vnd.otelo.myweb-v10.4.0+json',
#  'application/vnd.pgrst.object+json',
#  'application/vnd.pxs.frontconfiguration.v1+json',
#  'application/vnd.qon+json',
#  'application/vnd.radio-canada.neuro+json',
#  'application/vnd.rb.uim-v16+json',
#  'application/vnd.rbgemc+json',
#  'application/vnd.recipes.v1+json',
#  'application/vnd.scaleofuniverse.dave',
#  'application/vnd.siren+json',
#  'application/vnd.sm-standards-v1+json',
#  'application/vnd.softswiss.v1+json',
#  'application/vnd.softswiss.v2+json',
#  'application/vnd.solid-v1.0+json',
#  'application/vnd.sparebank1.v1+json',
#  'application/vnd.spring-boot.actuator.v3+json',
#  'application/vnd.sun.wadl+xml',
#  'application/vnd.swm.v4+json',
#  'application/vnd.tipico.payment.methods-v1+json',
#  'application/vnd.tipico.rethink-globals-v1+json',
#  'application/vnd.tipico.session-v1+json',
#  'application/vnd.treasuredata.v1+json',
#  'application/vnd.treasuredata.v1.js+json',
#  'application/vnd.unity',
#  'application/vnd.urbanairship+json',
#  'application/vnd.vimeo.error+json',
#  'application/vnd.vimeo.live.interaction_room_status+json',
#  'application/vnd.vimeo.video+json',
#  'application/vnd.welcome-offers+json',
#  'application/vnd.wg.cds_api+json',
#  'application/vnd.wolfram.mathematica.package',
#  'application/vnd.yt-ump',
#  'application/vndms-fontobject',
#  'application/vue',
#  'application/wasm',
#  'application/webp',
#  'application/woff',
#  'application/woff2',
#  'application/x',
#  'application/x-123',
#  'application/x-amz-json-1.0',
#  'application/x-amz-json-1.1',
#  'application/x-ani',
#  'application/x-asciicast',
#  'application/x-base64-frpc',
#  'application/x-binary',
#  'application/x-brotli',
#  'application/x-bzip2',
#  'application/x-compressed-tar',
#  'application/x-directory',
#  'application/x-download',
#  'application/x-empty',
#  'application/x-font',
#  'application/x-font-eot',
#  'application/x-font-l',
#  'application/x-font-opentype',
#  'application/x-font-otf',
#  'application/x-font-tff',
#  'application/x-font-truetype',
#  'application/x-font-truetype.ttf',
#  'application/x-font-ttf',
#  'application/x-font-ttf|application/octet-stream|font/ttf',
#  'application/x-font-woff',
#  'application/x-font-woff2',
#  'application/x-font-woff3',
#  'application/x-font-woffContent-Type',
#  'application/x-font/woff',
#  'application/x-fonts',
#  'application/x-frpc',
#  'application/x-go-sgf',
#  'application/x-gzip',
#  'application/x-html',
#  'application/x-httpd-ea-php70',
#  'application/x-httpd-ea-php72',
#  'application/x-httpd-ea-php73',
#  'application/x-httpd-php',
#  'application/x-httpd-php-source',
#  'application/x-httpd-php56',
#  'application/x-ico',
#  'application/x-icon',
#  'application/x-ilcs',
#  'application/x-java-pack200',
#  'application/x-javascript',
#  'application/x-javascript charset=utf-8',
#  'application/x-javascript, charset=UTF-8',
#  'application/x-javascript,public, max-age=86400',
#  'application/x-javascript,text/html',
#  'application/x-js',
#  'application/x-json',
#  'application/x-liquid',
#  'application/x-mpegURL',
#  'application/x-mpegurl',
#  'application/x-msdos-program',
#  'application/x-msdownload',
#  'application/x-msgpack',
#  'application/x-msmetafile',
#  'application/x-ndjson',
#  'application/x-object',
#  'application/x-octet-stream',
#  'application/x-octetstream',
#  'application/x-opentype',
#  'application/x-perl',
#  'application/x-photoshop',
#  'application/x-php',
#  'application/x-protobuf',
#  'application/x-rar-compressed',
#  'application/x-shared-scripts',
#  'application/x-shockwave-flash',
#  'application/x-silverlight-app',
#  'application/x-sqlite3',
#  'application/x-stuff',
#  'application/x-subrip',
#  'application/x-trash',
#  'application/x-troff',
#  'application/x-troff-man',
#  'application/x-troff-me',
#  'application/x-ttf',
#  'application/x-typekit-augmentation',
#  'application/x-unknown',
#  'application/x-unknown-content-type',
#  'application/x-urlencoded',
#  'application/x-webp',
#  'application/x-woff',
#  'application/x-woff2',
#  'application/x-www-form-urlencode',
#  'application/x-www-form-urlencoded',
#  'application/x-xpinstall',
#  'application/x-yaml',
#  'application/x-zip-compressed',
#  'application/x.prottp',
#  'application/x.vnd.acss.v1+json',
#  'application/x.volvogroup.com.incident.v1.0+json',
#  'application/xhtml+xml',
#  'application/xml',
#  'application/xslt+xml',
#  'application/zip',
#  'application:json',
#  'applications/font-woff2',
#  'applications/octet-stream',
#  'applicaton/json',
#  'applicaton/xml',
#  'applicattion/x-woff',
#  'appliciation/json',
#  'appliction/json',
#  'apr 16, 2019 12:16:15 pm org.apache.tika.config.initializableproblemhandler$3 handleinitializablepro',
#  'apr 16, 2019 12:16:29 pm org.apache.tika.config.initializableproblemhandler$3 handleinitializablepro',
#  'arraybuffer',
#  'assets/fonts/woff2/',
#  'audio',
#  'audio/aac',
#  'audio/aacp',
#  'audio/flac',
#  'audio/m4a',
#  'audio/midi',
#  'audio/mp3',
#  'audio/mp4',
#  'audio/mpeg',
#  'audio/mpeg, audio/x-mpeg, audio/x-mpeg-3, audio/mpeg3',
#  'audio/mpeg3',
#  'audio/mpegurl',
#  'audio/ogg',
#  'audio/unknown',
#  'audio/vnd.wave',
#  'audio/wav',
#  'audio/wave',
#  'audio/webm',
#  'audio/x-aac',
#  'audio/x-m4a',
#  'audio/x-m4p',
#  'audio/x-mpegurl',
#  'audio/x-riff',
#  'audio/x-wav',
#  'aug 17, 2018 1:18:20 pm org.apache.tika.config.initializableproblemhandler$3 handleinitializableprob',
#  'aug 17, 2018 1:19:32 pm org.apache.tika.config.initializableproblemhandler$3 handleinitializableprob',
#  'aug 17, 2018 1:21:26 pm org.apache.tika.config.initializableproblemhandler$3 handleinitializableprob',
#  'auto',
#  'auto-detect',
#  'banners',
#  'bin/application',
#  'binary/data',
#  'binary/octed-stream',
#  'binary/octet-stream',
#  'charset=ISO-8859-1',
#  'charset=UTF-8',
#  'charset=euc-jp',
#  'charset=utf-8',
#  'content-type: image/png',
#  'content/css/font/otf',
#  'content/unknown',
#  'css',
#  'data:image/jpeg',
#  'dealnews/json',
#  'directory',
#  'false',
#  'file/unknown',
#  'font-ttf',
#  'font-woff',
#  'font-woff2',
#  'font/',
#  'font/.otf',
#  'font/.ttf',
#  'font/collection',
#  'font/eot',
#  'font/font-woff',
#  'font/font-woff2',
#  'font/opentype',
#  'font/otf',
#  'font/sfnt',
#  'font/svg',
#  'font/truetype',
#  'font/ttf',
#  'font/woff',
#  'font/woff2',
#  'font/woff2|application/octet-stream|font/x-woff2',
#  'font/woff|application/font-woff|application/x-font-woff|application/octet-stream',
#  'font/x-font-otf',
#  'font/x-font-ttf',
#  'font/x-font-woff',
#  'font/x-font-woff2',
#  'font/x-otf',
#  'font/x-webp',
#  'font/x-woff',
#  'font/x-woff2',
#  'fonts',
#  'fonts/font-otf',
#  'fonts/woff',
#  'fonts/woff2',
#  'gif',
#  'html',
#  'html_type',
#  'httpd/unix-directory',
#  'i',
#  'iamge/avif',
#  'iamge/webp',
#  'ico',
#  'im',
#  'imag/Gif',
#  'imag/x-icon',
#  'image',
#  'image%2Fsvg%2Bxml',
#  'image-jpeg',
#  'image.jpeg',
#  'image/',
#  'image/$1',
#  "image/'. png .'",
#  'image/*',
#  'image/.avif',
#  'image/.gif',
#  'image/.jpg',
#  'image/.pdf',
#  'image/.png',
#  'image/.webp',
#  'image/25',
#  'image/35',
#  'image/9',
#  'image/Audiolibrix.Shop.Components.Helpers.ImageResizeHelper+ImageResizeSettings',
#  'image/BMP',
#  'image/GIF',
#  'image/Gif',
#  'image/Icon',
#  'image/JPEG',
#  'image/JPG',
#  'image/Jpeg',
#  'image/MPO',
#  'image/PNG',
#  'image/Png',
#  'image/WEBP',
#  'image/Webp',
#  'image/apng',
#  'image/avif',
#  'image/avif,image/webp,*/*',
#  'image/bmp',
#  'image/br/arquivos/ids/186469_2',
#  'image/cur',
#  'image/dicomp',
#  'image/font-woff+.woff',
#  'image/gif',
#  'image/heic',
#  'image/heif',
#  'image/icns',
#  'image/ico',
#  'image/icon',
#  'image/image',
#  'image/image/png',
#  'image/jfif',
#  'image/jp2',
#  'image/jpeg',
#  'image/jpeg ',
#  'image/jpeg jpg',
#  'image/jpeg, image/jpg',
#  'image/jpeg, image/pjpeg',
#  'image/jpeg,8888888888888888',
#  'image/jpeg,charset=Shift-JIS',
#  'image/jpeg,image/pjpeg',
#  'image/jpeg,text/html',
#  'image/jpeg/png/jpg/gif',
#  'image/jpg',
#  'image/jpg?v=1676040768',
#  'image/jpg_thumb_207_207',
#  'image/jpqg',
#  'image/js',
#  'image/json',
#  'image/jxl',
#  'image/jxr',
#  'image/ktx2',
#  'image/list',
#  'image/magick',
#  'image/peg',
#  'image/pipeg',
#  'image/pjpeg',
#  'image/pjpg',
#  'image/png',
#  'image/png ',
#  'image/png, image/jpeg',
#  'image/png,8888888888888888',
#  'image/png,image/jpeg',
#  'image/png,text/html',
#  'image/png?v=1716222340',
#  'image/svg',
#  'image/svg+xml',
#  'image/thumbnail',
#  'image/tif',
#  'image/tiff',
#  'image/ttf',
#  'image/undefined',
#  'image/unknown',
#  'image/vnd.adobe.photoshop',
#  'image/vnd.cappasity',
#  'image/vnd.microsoft.icon',
#  'image/vnd.microsoft.icon, text/html',
#  'image/vnd.mozilla.apng',
#  'image/vnd.wap.wbmp',
#  'image/web',
#  'image/webP',
#  'image/webm',
#  'image/webp',
#  'image/wepb',
#  'image/woff',
#  'image/woff2',
#  'image/x-generic',
#  'image/x-ico',
#  'image/x-icon',
#  'image/x-icon,text/html',
#  'image/x-ms-bmp',
#  'image/x-png',
#  'image/x-portable-graymap',
#  'image/x-tga',
#  'image/x-webp',
#  'image/x-win-bitmap',
#  'image/x-xbitmap',
#  'image/x.fb.keyframes',
#  'image/xicon',
#  'image\\.jpg',
#  'image\\jpeg',
#  'images/downloads',
#  'images/gif',
#  'images/home',
#  'images/jpeg',
#  'images/png',
#  'images/svg',
#  'images/webp',
#  'images/x-icon',
#  'img',
#  'img.jpg',
#  'img/gif',
#  'img/html',
#  'img/jpeg',
#  'img/jpg',
#  'img/png',
#  'inode/x-empty',
#  'invalid/invalid',
#  'javascript',
#  'javascript charset=UTF-8',
#  'javascript/vue',
#  'javascript/x-javascript',
#  'jpeg',
#  'jpg',
#  'jpg/image',
#  'js',
#  'json',
#  'json/application',
#  'jul 30, 2018 6:44:16 am org.apache.tika.config.initializableproblemhandler$3 handleinitializableprob',
#  'jul 30, 2018 6:44:28 am org.apache.tika.config.initializableproblemhandler$3 handleinitializableprob',
#  'jul 30, 2018 6:44:34 am org.apache.tika.config.initializableproblemhandler$3 handleinitializableprob',
#  'm',
#  'mage/x-icon',
#  'max-age=31536000',
#  'max-age=31536000, public',
#  'max-age=604800',
#  'max-age=700000',
#  'max-age=86400',
#  'mime',
#  'mime/vtt',
#  'misc',
#  'model/gltf+json',
#  'model/gltf-binary',
#  'mp4',
#  'multipart/byteranges',
#  'multipart/form-data',
#  'multipart/mixed',
#  'multipart/related',
#  'multipart/x-mixed-replace',
#  'none',
#  'nov 07, 2019 9:37:16 pm org.apache.tika.config.initializableproblemhandler$3 handleinitializableprob',
#  'null',
#  'octet-stream',
#  'octet/application-stream',
#  'otf',
#  'plain/text',
#  'png',
#  'public, max-age=31536000',
#  'public, max-age=3600',
#  'resim/webp',
#  'riot/tag',
#  'rtmp/mp4',
#  'script/javascript',
#  'svg',
#  'tea/earlgray',
#  'text',
#  'text%2fhtml',
#  'text-html',
#  'text-javascript',
#  'text-plain',
#  'text/*',
#  'text/HTML',
#  'text/JavaScript',
#  'text/Javascript',
#  'text/aes',
#  'text/base64.jpg',
#  'text/cache-manifest',
#  'text/calendar',
#  'text/comma-separated-values',
#  'text/css',
#  'text/css,*/*',
#  'text/css,8888888888888888',
#  'text/css,no-store, no-cache, must-revalidate, max-age=86400',
#  'text/css,text/css',
#  'text/css,text/html',
#  'text/csv',
#  'text/ecmascript',
#  'text/enriched',
#  'text/event-stream',
#  'text/fragment+html',
#  'text/html',
#  'text/html ',
#  'text/html charset=utf-8',
#  'text/html, charset=UTF-8',
#  'text/html, charset=iso-8859-1',
#  'text/html, charset=utf-8',
#  'text/html, utf-8',
#  'text/html,text/html',
#  'text/html-by-ajax',
#  'text/img',
#  'text/javacript',
#  'text/javascript',
#  'text/javascript  charset=utf-8',
#  'text/javascript charset=UTF-8',
#  'text/javascript charset=utf-8',
#  'text/javascript utf-8',
#  'text/javascript+json',
#  'text/javascript, charset=utf-8',
#  'text/javascript,8888888888888888',
#  'text/javascript,charset=utf-8',
#  'text/javascript/application/x-javascript',
#  'text/javascriptn',
#  'text/javsacript',
#  'text/js',
#  'text/json',
#  'text/json)',
#  'text/jsonp',
#  'text/jsx',
#  'text/less',
#  'text/markdown',
#  'text/nozip',
#  'text/octet',
#  'text/octet-stream',
#  'text/php',
#  'text/plain',
#  'text/plain charset = UTF-8',
#  'text/plain charset: UTF-8',
#  'text/plain charset=UTF-8',
#  'text/plain image/jpeg image/png',
#  'text/plan',
#  'text/platin',
#  'text/png',
#  'text/properties',
#  'text/prs.lines.tag',
#  'text/remix-deferred',
#  'text/richtext',
#  'text/script',
#  'text/srt',
#  'text/sveltekit-data',
#  'text/tab-separated-values',
#  'text/template',
#  'text/text',
#  'text/twig',
#  'text/txt',
#  'text/uri-list',
#  'text/vnd.a',
#  'text/vnd.reddit.partial+html',
#  'text/vnd.trolltech.linguist',
#  'text/vnd.turbo-stream.html',
#  'text/vtt',
#  'text/x-adasrc',
#  'text/x-asm',
#  'text/x-c',
#  'text/x-chdr',
#  'text/x-component',
#  'text/x-dsrc',
#  'text/x-gettext-translation',
#  'text/x-go',
#  'text/x-handlebars-template',
#  'text/x-html-fragment',
#  'text/x-java-source',
#  'text/x-javascript',
#  'text/x-js',
#  'text/x-json',
#  'text/x-markdown',
#  'text/x-ndjson',
#  'text/x-org',
#  'text/x-pascal',
#  'text/x-perl',
#  'text/x-python',
#  'text/x-sass',
#  'text/x-script.perl',
#  'text/x-scss',
#  'text/x-template',
#  'text/x-ubf',
#  'text/x.template.html',
#  'text/xml',
#  'text/xml ',
#  'text/xsl',
#  'text/yaml',
#  'text\\json',
#  'themes/sgifusion-porto/video/mp4',
#  'themes/sgifusion-porto/video/webm',
#  'tk/lws',
#  'tk/relay',
#  'ttf',
#  'ttf/x-font',
#  'type',
#  'type/subtype',
#  'undefined',
#  'unknown',
#  'unknown/nmmm',
#  'unknown/unknown',
#  'utf-8',
#  'vedip/webp',
#  'vid/mp4',
#  'video/.mp4',
#  'video/3gpp',
#  'video/MP2T',
#  'video/WebM',
#  'video/iso.segment',
#  'video/jpeg',
#  'video/m4v',
#  'video/mgep',
#  'video/mp2t',
#  'video/mp4',
#  'video/mpeg',
#  'video/mpeg4',
#  'video/ogg',
#  'video/quicktime',
#  'video/vnd.dlna.mpeg-tts',
#  'video/vnd.objectvideo',
#  'video/wbem',
#  'video/webm',
#  'video/webp',
#  'video/x-flv',
#  'video/x-m4v',
#  'video/x-matroska',
#  'video/x-ms-wmv',
#  'video/x-msvideo',
#  'video/x-pv-mp4',
#  'vnd.microsoft.icon',
#  'vnd.travelcircus.campaign.collection+json',
#  'vnd.travelcircus.list+json',
#  'vnd.travelcircus.offer.collection+json',
#  'webfonts/woff2',
#  'webp',
#  'webp/image',
#  'woff',
#  'woff type',
#  'woff/x-font',
#  'woff2',
#  'x-application/woff2',
#  'x-component',
#  'x-font/eot',
#  'x-font/otf',
#  'x-font/ttf',
#  'x-font/woff',
#  'x-font/woff2',
#  'x-font/x-woff2',
#  'x-javascript',
#  'x-mapp-cgi',
#  'x-png',
#  'x￢ﾀﾓfont/ttf',
#  '{image/jpeg}',
#  '{image/png}',
#  'ﾠimage/jpeg'}

# %%
# correlation mime types

# filter for relevant ID of interesect websites
ids_df = website_df[['dns', '_id']]
ids_df = ids_df.rename(columns={'dns': 'domain'})
intersect_ids = pd.merge(intersect_domains, ids_df, how='inner', on='domain')
mime_types_intersect_df = warmed_up_measurements_df[mime_types_df['website_id'].isin(intersect_ids['domain'])]

#clean mime types hard because everybody can write anything as mimetype name in there 
# instead --> look for most common types
mime_types_intersect_df
# add occurances of mime types to website_df_insersect

# %%
website_df
# Out:
#            _id  has_website  has_error                      dns  \
# 0       940334         True       True    crohn-colitis-info.at
# 1       458600         True       True        robertaspizza.com
# 2       955456         True       True      techdifferences.com
# 3       437664         True       True              ufabet.navy
# 4       653103         True       True      eclecticrecipes.com
# ...        ...          ...        ...                      ...
# 999995  585227         True      False          conflictarm.com
# 999996  766938         True      False  batepapocommulheres.com
# 999997  658198         True      False             nezavisim.tv
# 999998  564741         True      False              aare.edu.au
# 999999  726729         True      False                    pv.de
#
#        number_dns_queries  number_objects_loaded  number_queried_servers  \
# 0                    None                  102.0                     6.0
# 1                    None                   60.0                    12.0
# 2                    None                   40.0                    12.0
# 3                    None                   24.0                     3.0
# 4                    None                   31.0                    13.0
# ...                   ...                    ...                     ...
# 999995               None                    0.0                     0.0
# 999996               None                    0.0                     0.0
# 999997               None                    0.0                     0.0
# 999998               None                    0.0                     0.0
# 999999               None                    0.0                     0.0
#
#         number_non_origin_servers  number_mime_types  bytes_downladed  \
# 0                             5.0               14.0        3646848.0
# 1                            11.0               15.0        3256246.0
# 2                            10.0               15.0         950706.0
# 3                             1.0                5.0         604585.0
# 4                            11.0               17.0        1352135.0
# ...                           ...                ...              ...
# 999995                        0.0                0.0              0.0
# 999996                        0.0                0.0              0.0
# 999997                        0.0                0.0              0.0
# 999998                        0.0                0.0              0.0
# 999999                        0.0                0.0              0.0
#
#         har_file
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ...          ...
# 999995     False
# 999996     False
# 999997     False
# 999998     False
# 999999     False
#
# [1000000 rows x 11 columns]

# %%
sample = len(website_df['number_objects_loaded'])
not_a_website = website_df['number_objects_loaded'].isna().sum()

plt.pie([sample-not_a_website, not_a_website], labels=['websites', 'non website domains'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb92e708c10>,
#   <matplotlib.patches.Wedge at 0x7fb933514130>],
#  [Text(-0.7778174593052023, 0.7778174593052024, 'websites'),
#   Text(0.7778174593052022, -0.7778174593052025, 'non website domains')])

# %%
website_df = website_df[website_df['number_objects_loaded'].notna()]
website_df['number_objects_loaded'].isna().sum()
# Out:
# 0

# %%
# calculate in kb
website_df['bytes_downladed'] = website_df['bytes_downladed'].div(1000).round()

# %%
website_df
# Out:
#      _id               dns number_dns_queries  number_objects_loaded  \
# 0      1        google.com               None                   34.0
# 2      3     microsoft.com               None                   94.0
# 3      4      facebook.com               None                   69.0
# 5      6    googleapis.com               None                    4.0
# 6      7         apple.com               None                   62.0
# ..   ...               ...                ...                    ...
# 493  494            ft.com               None                  143.0
# 496  497  virtualearth.net               None                  104.0
# 497  498    trustpilot.com               None                  141.0
# 498  499  visualstudio.com               None                  223.0
# 499  500        hotjar.com               None                  204.0
#
#      number_queried_servers  number_non_origin_servers  number_mime_types  \
# 0                       8.0                        4.0               13.0
# 2                      16.0                        8.0               22.0
# 3                       6.0                        4.0               10.0
# 5                       2.0                        1.0                2.0
# 6                       5.0                        2.0               16.0
# ..                      ...                        ...                ...
# 493                    19.0                       11.0               19.0
# 496                     6.0                        3.0               12.0
# 497                    16.0                       13.0               19.0
# 498                    19.0                       17.0               21.0
# 499                    36.0                       34.0               25.0
#
#      bytes_downladed alexa_category
# 0             1054.0           None
# 2             3634.0           None
# 3             2659.0           None
# 5               18.0           None
# 6             9552.0           None
# ..               ...            ...
# 493           1915.0           None
# 496           1532.0           None
# 497           2554.0           None
# 498           4909.0           None
# 499           2600.0           None
#
# [375 rows x 9 columns]

# %%
# number of bytes downloaded
diagram = sns.distplot(website_df['bytes_downladed'], kde=False, bins=40)
diagram.set(xlabel='bytes downloaded in kB', ylabel='number of websites')
# Out:
# [Text(0.5, 0, 'bytes downloaded in kB'), Text(0, 0.5, 'number of websites')]

# %%
# number of bytes downloaded
diagram = sns.distplot(website_df['number_mime_types'], kde=False, bins=40)
diagram.set(xlabel='number of mime_types', ylabel='number of websites')
# Out:
# [Text(0.5, 0, 'number of mime_types'), Text(0, 0.5, 'number of websites')]

# %%
# queried servers compared to non origin servers
sns.set_style('darkgrid')
sns.jointplot(x='number_queried_servers', y='number_non_origin_servers', data=website_df)

# %%
google = mime_types_df.loc[mime_types_df['website_id'] == 1]

microsoft = mime_types_df.loc[mime_types_df['website_id'] == 3]

facebook = mime_types_df.loc[mime_types_df['website_id'] == 4]

apple = mime_types_df.loc[mime_types_df['website_id'] == 7]

# %%
sns.barplot(data=google, x="occurences", y="mime_type")
# Out:
# <AxesSubplot:xlabel='occurences', ylabel='mime_type'>

# %%
sns.barplot(data=microsoft, x="occurences", y="mime_type")
# Out:
# <AxesSubplot:xlabel='occurences', ylabel='mime_type'>

# %%
sns.barplot(data=facebook, x="occurences", y="mime_type")
# Out:
# <AxesSubplot:xlabel='occurences', ylabel='mime_type'>

# %%
sns.barplot(data=apple, x="occurences", y="mime_type")
# Out:
# <AxesSubplot:xlabel='occurences', ylabel='mime_type'>

# %%
sns.pairplot(website_df, palette='Blues')
